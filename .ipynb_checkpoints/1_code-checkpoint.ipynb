# %% [markdown]
# # The White Lotus
# **Episode 1 (Arrivals)**

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('data.xlsx', sheet_name='episode1')
data
# Out:
#       initiator responder                                           dialogue
# 0   PASSENGER 1     SHANE  You headed home? Yeah We were at the Amanari. ...
# 1        OLIVIA     PAULA  Oh my God, who are these people?  So, these tw...
# 2        NICOLE    OLIVIA  Hey, girls.  What, Mom?  Liv, come up front. I...
# 3        ARMOND      LANI  Here they come.  Wave, Lani. There we are.  Wa...
# 4       BELINDA    NICOLE                                Welcome. Thank you.
# ..          ...       ...                                                ...
# 89       OLIVIA     QUINN  Quinn, what are you doing in there? Are you fa...
# 90         MARK    NICOLE  Shit. Nicole, it’s the doctor. I told you, tod...
# 91         MARK     NURSE  Mark?  This is he.  Hi, do you have a minute f...
# 92       NICOLE      MARK  It’s gonna be okay, Mark. It’s… it’s gonna be ...
# 93       RACHEL     SHANE  We’re married.  We’re on our honeymoon.  Yeah....
#
# [94 rows x 3 columns]

# %%
df = (data
 .assign(sorted_pairs=lambda df_: df_.apply(lambda df_: '-'.join(sorted([df_['initiator'], df_['responder']])), axis=1))
 .assign(weight=lambda df_: df_.groupby(['sorted_pairs'])['sorted_pairs'].transform('count'))
 .assign(dialogue=lambda df_: df_.groupby(['sorted_pairs'])['dialogue'].transform(lambda df_: ' '.join(df_.unique())))
 .drop_duplicates('sorted_pairs')
 .drop(columns='sorted_pairs')
 .sort_values('weight', ascending=False)
)

# %%
def draw_graph(G, img_size=(10,6), k_dist=0.8):
    plt.figure(figsize=img_size)
    pos = nx.spring_layout(G, k=k_dist)
    nx.draw(G, pos , with_labels = True, width=0.4, node_color='lightblue', node_size=400)

G = nx.from_pandas_edgelist(df, source='initiator', target='responder', edge_attr=['weight'])
draw_graph(G, k_dist=0.9)

# %%
# show nodes in network
G.nodes
# Out:
# NodeView(('OLIVIA', 'PAULA', 'RACHEL', 'SHANE', 'ARMOND', 'LANI', 'TANYA', 'BELINDA', 'DILLON', 'MARK', 'QUINN', 'NICOLE', 'PASSENGER 1', 'CHRISTIE', 'DR REZZ', 'DARRELL', 'NURSE'))

# %%
# count nodes
len(G.nodes)
# Out:
# 17

# %%
# slice network
list(G.nodes)[:5]
# Out:
# ['OLIVIA', 'PAULA', 'RACHEL', 'SHANE', 'ARMOND']

# %%
G.nodes(1)
# Out:
# NodeDataView({'OLIVIA': None, 'PAULA': None, 'RACHEL': None, 'SHANE': None, 'ARMOND': None, 'LANI': None, 'TANYA': None, 'BELINDA': None, 'DILLON': None, 'MARK': None, 'QUINN': None, 'NICOLE': None, 'PASSENGER 1': None, 'CHRISTIE': None, 'DR REZZ': None, 'DARRELL': None, 'NURSE': None}, data=1)

# %%
# show edges
G.edges
# Out:
# EdgeView([('OLIVIA', 'PAULA'), ('OLIVIA', 'RACHEL'), ('OLIVIA', 'NICOLE'), ('OLIVIA', 'QUINN'), ('PAULA', 'RACHEL'), ('PAULA', 'NICOLE'), ('RACHEL', 'SHANE'), ('RACHEL', 'ARMOND'), ('SHANE', 'ARMOND'), ('SHANE', 'PASSENGER 1'), ('SHANE', 'LANI'), ('ARMOND', 'LANI'), ('ARMOND', 'DILLON'), ('ARMOND', 'TANYA'), ('ARMOND', 'MARK'), ('ARMOND', 'BELINDA'), ('ARMOND', 'CHRISTIE'), ('ARMOND', 'ARMOND'), ('ARMOND', 'QUINN'), ('ARMOND', 'NICOLE'), ('LANI', 'LANI'), ('LANI', 'BELINDA'), ('LANI', 'DR REZZ'), ('LANI', 'DARRELL'), ('LANI', 'TANYA'), ('TANYA', 'BELINDA'), ('TANYA', 'TANYA'), ('BELINDA', 'BELINDA'), ('BELINDA', 'NICOLE'), ('MARK', 'QUINN'), ('MARK', 'NICOLE'), ('MARK', 'NURSE'), ('QUINN', 'NICOLE')])

# %%
# count edges
len(G.edges)
# Out:
# 33

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
dmax = max(degree_sequence)
print(dmax)
# Out:
# 12

# %%
plt.bar(*np.unique(degree_sequence, return_counts=True))
plt.title("Degree Histogram")
plt.xlabel("Degree")
plt.ylabel("# of Nodes")
# Out:
# Text(0, 0.5, '# of Nodes')

# %%
degree_centrality = nx.degree_centrality(G)

# %%
dict(sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'ARMOND': 0.75,
#  'LANI': 0.5,
#  'BELINDA': 0.375,
#  'NICOLE': 0.375,
#  'TANYA': 0.3125,
#  'OLIVIA': 0.25,
#  'RACHEL': 0.25,
#  'SHANE': 0.25,
#  'MARK': 0.25,
#  'QUINN': 0.25,
#  'PAULA': 0.1875,
#  'DILLON': 0.0625,
#  'PASSENGER 1': 0.0625,
#  'CHRISTIE': 0.0625,
#  'DR REZZ': 0.0625,
#  'DARRELL': 0.0625,
#  'NURSE': 0.0625}

# %%
deg_ser = pd.Series(dict(sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True)))

# %%
fig, ax = plt.subplots(figsize=(6,4), dpi=150)

for font in ['xtick.color', 'ytick.color', 'axes.labelcolor']:
    plt.rcParams[font] = 'blue'

(deg_ser
.plot.barh(ax=ax, color='#696969')
)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
data = deg_ser

# Calculate the ECDF
x = np.sort(data)
y = np.arange(1, len(data)+1) / len(data)

# Plot the ECDF
plt.plot(x, y, marker='.', linestyle='none')

# Add axis labels and title
plt.xlabel('Data')
plt.ylabel('ECDF')
plt.title('Empirical Cumulative Distribution Function')

# Show the plot
plt.show()

# %%
deg_ser = pd.Series(dict(sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True)))

# %%
from pyvis.network import Network
net = Network(notebook=True, cdn_resources='remote', width='1000px', height='700px', bgcolor='#000000', font_color='yellow')

node_degree = dict(G.degree)

# set node size attribute
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G)
net.show('ep1.html')
# Out:
# ep1.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="ep1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# show node degreee
dict(G.degree)
# Out:
# {'OLIVIA': 4,
#  'PAULA': 3,
#  'RACHEL': 4,
#  'SHANE': 4,
#  'ARMOND': 12,
#  'LANI': 8,
#  'TANYA': 5,
#  'BELINDA': 6,
#  'DILLON': 1,
#  'MARK': 4,
#  'QUINN': 4,
#  'NICOLE': 6,
#  'PASSENGER 1': 1,
#  'CHRISTIE': 1,
#  'DR REZZ': 1,
#  'DARRELL': 1,
#  'NURSE': 1}

# %%
# show degree centrality
centrality_dict = nx.degree_centrality(G)
centrality_dict
# Out:
# {'OLIVIA': 0.25,
#  'PAULA': 0.1875,
#  'RACHEL': 0.25,
#  'SHANE': 0.25,
#  'ARMOND': 0.75,
#  'LANI': 0.5,
#  'TANYA': 0.3125,
#  'BELINDA': 0.375,
#  'DILLON': 0.0625,
#  'MARK': 0.25,
#  'QUINN': 0.25,
#  'NICOLE': 0.375,
#  'PASSENGER 1': 0.0625,
#  'CHRISTIE': 0.0625,
#  'DR REZZ': 0.0625,
#  'DARRELL': 0.0625,
#  'NURSE': 0.0625}

# %%
centrality_df = pd.DataFrame.from_dict(centrality_dict, orient='index', columns=['centrality'])
(centrality_df
 .sort_values('centrality', ascending=False)[0:10]
 .plot.barh()
)
# Out:
# <AxesSubplot:>

# %%
# show betweenness
betweenness_dict = nx.betweenness_centrality(G)
betweenness_dict
# Out:
# {'OLIVIA': 0.01111111111111111,
#  'PAULA': 0.0027777777777777775,
#  'RACHEL': 0.08152777777777778,
#  'SHANE': 0.14875000000000002,
#  'ARMOND': 0.5462499999999999,
#  'LANI': 0.2583333333333333,
#  'TANYA': 0.0,
#  'BELINDA': 0.032777777777777774,
#  'DILLON': 0.0,
#  'MARK': 0.125,
#  'QUINN': 0.02375,
#  'NICOLE': 0.11138888888888886,
#  'PASSENGER 1': 0.0,
#  'CHRISTIE': 0.0,
#  'DR REZZ': 0.0,
#  'DARRELL': 0.0,
#  'NURSE': 0.0}

# %%
# show betweeness plot
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['betweenness'])
(betweenness_df
 .sort_values('betweenness', ascending=False)[0:10]
 .plot.barh()
)
# Out:
# <AxesSubplot:>

# %%
# show closeness
closeness_dict = nx.closeness_centrality(G)
closeness_dict
# Out:
# {'OLIVIA': 0.42105263157894735,
#  'PAULA': 0.41025641025641024,
#  'RACHEL': 0.5161290322580645,
#  'SHANE': 0.5517241379310345,
#  'ARMOND': 0.7272727272727273,
#  'LANI': 0.5517241379310345,
#  'TANYA': 0.48484848484848486,
#  'BELINDA': 0.5333333333333333,
#  'DILLON': 0.43243243243243246,
#  'MARK': 0.5161290322580645,
#  'QUINN': 0.5161290322580645,
#  'NICOLE': 0.5517241379310345,
#  'PASSENGER 1': 0.36363636363636365,
#  'CHRISTIE': 0.43243243243243246,
#  'DR REZZ': 0.36363636363636365,
#  'DARRELL': 0.36363636363636365,
#  'NURSE': 0.34782608695652173}

# %%
# show closeness plot
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['closeness'])
(closeness_df
 .sort_values('closeness', ascending=False)[0:10]
 .plot.barh()
)
# Out:
# <AxesSubplot:>
