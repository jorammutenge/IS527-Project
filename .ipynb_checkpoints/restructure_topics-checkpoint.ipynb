# %%
import pandas as pd
import numpy as np
import gensim
from gensim import corpora
from gensim.parsing.preprocessing import remove_stopwords
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag
# nltk.download('averaged_perceptron_tagger')

# %%
sheets = ['episode1', 'episode2', 'episode3', 'episode4', 'episode5', 'episode6']
data = pd.concat([pd.read_excel('data.xlsx', sheet_name = sheet) for sheet in sheets])

# %%
df = (data
 .assign(dialogue=lambda df_: df_.dialogue.str.replace('\s+', ' ', regex=True).str.strip(),
#          length=lambda df_: df_.dialogue.str.len().astype('int32')
        )
 .assign(sorted_pairs=lambda df_: df_.apply(lambda df_: '-'.join(sorted([df_['initiator'], df_['responder']])), axis=1))
 .assign(weight=lambda df_: df_.groupby(['sorted_pairs'])['sorted_pairs'].transform('count'))
 .assign(dialogue=lambda df_: df_.groupby(['sorted_pairs'])['dialogue'].transform(lambda df_: ' '.join(df_.unique())))
 .drop_duplicates('sorted_pairs')
 .drop(columns='sorted_pairs')
#  .head(30)
#  .sort_values('length', ascending=False)
#  .iloc[10, 2]
)

# %%
# func to add topics
def add_topic_labels(df):
    # create a list of documents from the 'dialogue' column
    documents = list(df['dialogue'])

    # define stop words, tags to remove, and words to remove
    stop_words = stopwords.words('english')
    removal = ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
    remove_words = ['like', 'gone', 'know', 'right', 'na', 'gon', 'yeah', 'really', 'okay',
                    'get', 'gonna', 'well', 'thank', 'oh', 'uh', 'hi', 'got', 'um', 'go',
                    'would', 'great', 'come', 'hey', 'wanna', 'hmm', 'mr', 'yes', 'good']

    # remove stop words and unwanted words
    tokenized_docs = [[token for token in gensim.utils.simple_preprocess(doc) if token not in stop_words and token not in remove_words] for doc in documents]

    # remove tags
    tagged_docs = [nltk.pos_tag(doc) for doc in tokenized_docs]
    tokenized_docs = [[token for token, pos in doc if pos not in removal] for doc in tagged_docs]

    # create a dictionary from the tokenized documents
    dictionary = corpora.Dictionary(tokenized_docs)

    # create a bag-of-words representation of the documents
    corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

    # train an LDA model on the corpus
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                id2word=dictionary,
                                                num_topics=5,
                                                random_state=42,
                                                passes=10)

    # extract the top fifteen words for each topic
    topic_labels = []
    for doc in tokenized_docs:
        bow = dictionary.doc2bow(doc)
        topics = lda_model.get_document_topics(bow)
        top_fifteen_words = [dictionary[word] for word, prob in sorted(lda_model.get_topic_terms(max(topics, key=lambda x: x[1])[0], topn=15), key=lambda x: x[1], reverse=True)]
        topic_labels.append(top_fifteen_words)

    # add the topic labels as a new column in the dataframe
    df['topic'] = topic_labels
    return df

# %%
# Define the names to create DataFrames for
chosen_names = ['NICOLE', 'TANYA', 'RACHEL', 'SHANE', 'ARMOND', 'PAULA', 'OLIVIA']

# Loop through the chosen names and create a new DataFrame for each one
for name in chosen_names:
    # Select rows where the name appears in either initiator or responder
    new_df = df[(df['initiator'] == name) | (df['responder'] == name)]
    
    # Create a new DataFrame with the selected rows
    globals()[f'{name}_df'] = pd.DataFrame(new_df)

# %%
# func to add word_count column
def tweak_df(df):
    return (df
             .assign(word_count=lambda df_: df_.dialogue.str.len().astype('int16'))
             .astype({'weight': 'int8'})
             .sort_values('word_count', ascending=False)
             .reset_index()
             .drop(columns='index')
            )

# list of dataframes to tweak
tweak_these = [NICOLE_df, TANYA_df, RACHEL_df, SHANE_df, ARMOND_df, PAULA_df, OLIVIA_df]

for i in range(len(tweak_these)):
    tweak_these[i] = tweak_df(tweak_these[i])

NICOLE_df, TANYA_df, RACHEL_df, SHANE_df, ARMOND_df, PAULA_df, OLIVIA_df = tweak_these


# list of dataframes to add topics to
topic_df = [NICOLE_df, TANYA_df, RACHEL_df, SHANE_df, ARMOND_df, PAULA_df, OLIVIA_df]

for i in range(len(topic_df)):
    topic_df[i] = add_topic_labels(topic_df[i])

NICOLE_df, TANYA_df, RACHEL_df, SHANE_df, ARMOND_df, PAULA_df, OLIVIA_df = topic_df

# %% [markdown]
# ## Topic conversations of interesting characters

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rcParams


# SET VIZ TEMPLATE
# colors
YELLOW='yellow'
BLACK='#1a1a1a'
GREY='#696969'
WHITE='white'

# fonts
futura_font_path = 'graphfonts/Futura/futura-medium-condensed.ttf'
FUTURA = fm.FontProperties(fname=futura_font_path)

paypal_font_path = 'graphfonts/Paypal/PayPalSansSmall-Regular.ttf'
PAYPAL = fm.FontProperties(fname=paypal_font_path)

DPI=200

# %%
def plot_word_grid(words, suptitle):
    # Define the figure size and background color
    fig = plt.figure(figsize=(8, 4), facecolor=BLACK, dpi=DPI)

    # Set the title
    fig.suptitle(suptitle, fontproperties=FUTURA, color='white', fontsize=12, y=.93)

    # Define the layout of the subplots
    layout = (5, 5)

    # Create subplots and add words to them
    for i, word in enumerate(words):
        ax = fig.add_subplot(*layout, i+1)
        ax.set_facecolor(BLACK)
        ax.text(0.5, 0.5, word, fontsize=10, ha='center', va='center', fontproperties=PAYPAL, color=YELLOW)

        # Remove spines and tick labels
        for side in 'top,right,bottom,left'.split(','):
            ax.spines[side].set_visible(False)
        ax.tick_params(axis='both', which='both', length=0)
        ax.set_xticklabels([])
        ax.set_yticklabels([])

    # Adjust the spacing between subplots
    fig.subplots_adjust(hspace=0.2, wspace=0.2)
    
    # Show the figure
    plt.show()

# %%
ARMOND_df
# Out:
#    initiator  responder                                           dialogue  \
# 0     ARMOND      SHANE  Oh, Mr. Patton and Ms. Undecided. You finding ...
# 1     ARMOND       MARK  Oh, Mr.. How can I help you? Uh, my son and I ...
# 2     ARMOND     DILLON  What? What is it? Um, Lani is in your office, ...
# 3     ARMOND       LANI  Here they come. Wave, Lani. There we are. Wave...
# 4     ARMOND    BELINDA  Belinda, Ms. Macuhwad is in need of treatment....
# 5     ARMOND      TANYA  Are you Ms. MacQoowod? Quoid. One syllable. Ma...
# 6     ARMOND     NICOLE  Mr. and Mrs.. Hello. I’m Armond, the resort ma...
# 7     ARMOND     RACHEL  I’m presuming Mr. Shane and Mrs. Rachel? Oh! T...
# 8   CHRISTIE     ARMOND  Dr. Rezz is on his way. But he is coming from ...
# 9     ARMOND      KITTY  Aloha! Welcome. Hi. I have a special table for...
# 10    OLIVIA     ARMOND  Excuse me. Yes? Where’s the lost and found? Lo...
# 11     PAULA     ARMOND  Yeah. I left it on the beach. It’s olive green...
# 12   LORENZO     ARMOND  Do you know who you’re dealing with? His fathe...
# 13    ARMOND      HUTCH  What? Some lady found this on the beach and ga...
# 14      JOHN     ARMOND  John, how are you? Yes. Okay, well– All right,...
# 15    ARMOND  MR FERRER  Aloha. This is Mr. Ferrer, in the Bredford sui...
# 16     QUINN     ARMOND  Are there sharks? They are actually a family o...
# 17    ARMOND     ARMOND  Oh. God. What is this? Can somebody clean this...
#
#     weight  word_count                                              topic
# 0       18        8129  [suite, room, pineapple, want, think, mother, ...
# 1       20        3405  [morning, enjoy, aloha, lost, green, ladies, f...
# 2       15        3102  [fuck, fucking, baby, lani, thought, shit, thi...
# 3        6        2370  [lani, room, fuck, christie, think, want, call...
# 4        8        2299  [fuck, fucking, baby, lani, thought, shit, thi...
# 5        4        2007  [need, belinda, could, behind, one, boat, toda...
# 6       15        1637  [morning, enjoy, aloha, lost, green, ladies, f...
# 7        7        1165  [suite, room, pineapple, want, think, mother, ...
# 8        6        1060  [lani, room, fuck, christie, think, want, call...
# 9        6        1042  [fuck, fucking, baby, lani, thought, shit, thi...
# 10      11        1001  [morning, enjoy, aloha, lost, green, ladies, f...
# 11       8         644  [morning, enjoy, aloha, lost, green, ladies, f...
# 12       1         504  [lani, room, fuck, christie, think, want, call...
# 13       8         368  [suite, room, pineapple, want, think, mother, ...
# 14       1         229  [suite, room, pineapple, want, think, mother, ...
# 15       1         174  [morning, enjoy, aloha, lost, green, ladies, f...
# 16       1         134  [need, belinda, could, behind, one, boat, toda...
# 17       5         134  [lani, room, fuck, christie, think, want, call...

# %%
SHANE_df
# Out:
#       initiator     responder  \
# 0        RACHEL         SHANE
# 1        ARMOND         SHANE
# 2         SHANE         KITTY
# 3         TANYA         SHANE
# 4   PASSENGER 1         SHANE
# 5         SHANE        OLIVIA
# 6         PAULA         SHANE
# 7         SHANE        DILLON
# 8         SHANE  RECEPTIONIST
# 9        NICOLE         SHANE
# 10        SHANE       BELINDA
# 11        SHANE       LORENZO
# 12        SHANE          MARK
# 13        SHANE         SHANE
# 14        SHANE     BARTENDER
# 15        SHANE          LANI
#
#                                              dialogue  weight  word_count  \
# 0   Oh, there’s a lobster bake tonight. Oh. Lobste...      46       16978
# 1   Oh, Mr. Patton and Ms. Undecided. You finding ...      18        8129
# 2   Honey? Hi. Hey, Mom. What’s up? Okay, so the s...      23        4958
# 3   Hey, everybody. Hey! Hey. Thank you for coming...      10        2309
# 4   You headed home? Yeah We were at the Amanari. ...       1         567
# 5   Hey. So, yesterday you were reading Freud and ...       3         475
# 6   We have a stylist choose our outfits and then ...       3         467
# 7   Hey, buddy. Hold on a second. Hey, if you see ...       3         465
# 8   Yeah, I have a message. She got her own room. ...       1         436
# 9   No, seriously. And the girls and I were gonna ...       3         426
# 10  I’m looking for Armond. I believe he’s gone fo...       1         261
# 11  Not yet, he gave me a bullshit number. Yeah. Y...       1         254
# 12  Hey, nice shiner. Ah. How’d that happen? You s...       3         213
# 13  Dude’s going down. You are fucked now, bro. Lo...       3          92
# 14  Double tequila. Sure, sounds good. Coming righ...       1          51
# 15                                        Um, hi. Hi.       1          11
#
#                                                 topic
# 0   [room, shane, think, honeymoon, suite, fucking...
# 1   [room, shane, think, honeymoon, suite, fucking...
# 2   [room, shane, think, honeymoon, suite, fucking...
# 3   [mother, god, think, pool, poor, water, want, ...
# 4   [mother, god, think, pool, poor, water, want, ...
# 5   [mother, god, think, pool, poor, water, want, ...
# 6   [mother, god, think, pool, poor, water, want, ...
# 7   [going, room, fuck, call, safe, trying, boat, ...
# 8   [room, shane, think, honeymoon, suite, fucking...
# 9   [going, room, fuck, call, safe, trying, boat, ...
# 10  [room, shane, think, honeymoon, suite, fucking...
# 11  [going, room, fuck, call, safe, trying, boat, ...
# 12  [see, pool, guy, going, nice, ah, happen, shin...
# 13  [going, room, fuck, call, safe, trying, boat, ...
# 14  [room, shane, think, honeymoon, suite, fucking...
# 15  [shane, room, honeymoon, mean, wait, guy, tell...

# %%
ARMOND_df.loc[5, ['initiator', 'responder', 'topic']]
# Out:
# initiator                                               ARMOND
# responder                                                TANYA
# topic        [need, belinda, could, behind, one, boat, toda...
# Name: 5, dtype: object

# %%
ARMOND_df.loc[5, 'topic']
# Out:
# ['need',
#  'belinda',
#  'could',
#  'behind',
#  'one',
#  'boat',
#  'today',
#  'tell',
#  'listen',
#  'want',
#  'lani',
#  'think',
#  'sharks',
#  'something',
#  'let']

# %%
plot_word_grid(ARMOND_df.loc[0, 'topic'], 'ARMOND and SHANE conversation topics')

# %%
plot_word_grid(SHANE_df.loc[0, 'topic'], 'SHANE and ARMOND conversation topics')

# %%
(ARMOND_df
 .loc[0:5, ['initiator', 'responder','topic']]
 .iloc[5, 2]
)

# %%
# Define the list of words
my_words = ['suite', 'room', 'pineapple', 'want', 'think', 'mother', 'sorry', 'boss', 'dinner', 'boat', 'aloha', 'pool', 'us', 'course', 'thanks']


fig = plt.figure(figsize=(8, 4), facecolor=BLACK, dpi=DPI)
fig.suptitle('ARMOND and SHANE conversation topics', fontproperties=FUTURA, color=WHITE, fontsize=12, y=.93)

# Define the layout of the subplots
layout = (5, 5)

# Create subplots and add words to them
for i, word in enumerate(my_words):
    ax = fig.add_subplot(*layout, i+1)
    ax.set_facecolor(BLACK)
    ax.text(0.5, 0.5, word, fontsize=10, ha='center', va='center', fontproperties=PAYPAL, color=YELLOW)
    
    # Remove spines and tick labels
    for side in 'top,right,bottom,left'.split(','):
        ax.spines[side].set_visible(False)
    ax.tick_params(axis='both', which='both', length=0)
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# Adjust the spacing between subplots
fig.subplots_adjust(hspace=0.2, wspace=0.2)
plt.show()

# %%
ARMOND_df.iloc[17,5]
